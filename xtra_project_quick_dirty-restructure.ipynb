# %%
import boto3
import pandas as pd
from io import StringIO , BytesIO
from datetime import datetime , timedelta

# %%
arg_date = '2022-12-23'
src_format = '%Y-%m-%d'
src_bucket = 'xetra-1234'
trg_bucket = 'targetbucket-1234'
columns = ['ISIN',  'Date', 'Time', 'StartPrice', 'MaxPrice', 'MinPrice','EndPrice', 'TradedVolume', 'NumberOfTrades']
trg_key = 'xetra_daiy_report_' + datetime.today().strftime('%Y-%m-%m_%H-%M-%S') + '.parquet'

# %%
arg_date_dt = datetime.strptime(arg_date ,src_format).date()-timedelta(days=1)

# %%
bucket.Object()

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket(src_bucket)
objects = [obj for obj in bucket.objects.all() if datetime.strptime(obj.key.split('/')[0],src_format).date() >= arg_date_dt]

# %%
def csv_to_df(filename):
    csv_obj = bucket.Object(key=filename).get().get('Body').read().decode('utf-8')
    data = StringIO(csv_obj)
    df = pd.read_csv(data, delimiter=",")
    return df

df_all = pd.concat([csv_to_df(obj.key) for obj in objects] , ignore_index=True)

# %%
df_all
# Out:
#                  ISIN Mnemonic               SecurityDesc  SecurityType
# 0        DE000A0HN5C6     DWNI     DEUTSCHE WOHNEN SE INH  Common stock  \
# 1        DE000A1J5RX9      O2D    TELEFONICA DTLD HLDG NA  Common stock
# 2        DE000A1ML7J1      VNA         VONOVIA SE NA O.N.  Common stock
# 3        DE000A13SX22      HLE   HELLA GMBH+CO. KGAA O.N.  Common stock
# 4        DE000PAT1AG3      PAT          PATRIZIA AG NA ON  Common stock
# ...               ...      ...                        ...           ...
# 1352560  GB00BLD4ZP54     CLTC    COINSHARES DIG.SEC.OEND           ETN
# 1352561  LU1923627332     RUSL  MUL-LYX.MSCI RUSSI.DIS.LS           ETF
# 1352562  US98956P1021      ZIM  ZIMMER BIOMET HLDGS DL-01  Common stock
# 1352563  US9224171002      VEO  VEECO INSTRUMENTS  DL-,01  Common stock
# 1352564  IT0005143547      EM8   ENERGICA MOTOR CO.S.P.A.  Common stock
#
#         Currency SecurityID        Date   Time  StartPrice  MaxPrice
# 0            EUR    2504314  2022-12-22  08:00      36.090    36.090  \
# 1            EUR    2504492  2022-12-22  08:00       2.500     2.506
# 2            EUR    2504501  2022-12-22  08:00      45.410    45.410
# 3            EUR    2504580  2022-12-22  08:00      62.000    62.080
# 4            EUR    2504817  2022-12-22  08:00      17.700    17.700
# ...          ...        ...         ...    ...         ...       ...
# 1352560      EUR    6479084  2022-12-31  16:46      19.324    19.324
# 1352561      EUR    5424594  2022-12-31  16:52      12.400    12.400
# 1352562      EUR    4582018  2022-12-31  20:30     113.100   113.100
# 1352563      EUR    6198311  2022-12-31  20:30      24.600    24.600
# 1352564      EUR    7026075  2022-12-31  20:30       3.100     3.100
#
#          MinPrice  EndPrice TradedVolume NumberOfTrades
# 0          35.830    35.860          912              7
# 1           2.490     2.506       162400             27
# 2          45.210    45.240        47143             89
# 3          62.000    62.080         4591              2
# 4          17.520    17.520          953              9
# ...           ...       ...          ...            ...
# 1352560    19.324    19.324            0              2
# 1352561    12.400    12.400         2645              2
# 1352562   113.100   113.100            0              1
# 1352563    24.600    24.600            0              1
# 1352564     3.100     3.100            0              1
#
# [1352565 rows x 14 columns]

# %%
df_all = df_all.loc[:, columns]

# %%
df_all.dropna(inplace=True)

# %% [markdown]
# ## Get the opening price per ISIN and day

# %%
df_all['opening_price'] = df_all.sort_values('Time').groupby(['ISIN','Date'])['StartPrice'].transform("first")

# %% [markdown]
# ## Get closing price per ISIN and Day

# %%
df_all['closing_price'] = df_all.sort_values('Time').groupby(['ISIN','Date'])['StartPrice'].transform("last")

# %% [markdown]
# ## Aggregrations

# %%
df_all = df_all.groupby(['ISIN','Date'], as_index=False).agg(opening_price_euro=('opening_price','min'),closing_price_euro=('closing_price','min'), minimun_price_euro=('MinPrice','min'),maximun_price_euro=('MaxPrice','max'), daily_traded_volume=('TradedVolume','sum'))

# %% [markdown]
# ## Percentage Change previous closing price

# %%
df_all['previous_closing_price'] = df_all.sort_values(by=['Date']).groupby(['ISIN'])['closing_price_euro'].shift(1)

# %%
df_all['percentage_change_prev%'] = ((df_all['closing_price_euro']-df_all['previous_closing_price'])/df_all['previous_closing_price'])*100

# %%
df_all.drop(columns=['previous_closing_price'],inplace=True)

# %%
df_all = df_all.round(decimals=2)

# %%
df_all = df_all[df_all.Date >= arg_date]

# %% [markdown]
# ## Write to s3

# %%
outbuffer =BytesIO()
df_all.to_parquet(outbuffer , index=False)
target_bucket = s3.Bucket(trg_bucket)
target_bucket.put_object(Body = outbuffer.getvalue() , Key = trg_key)
# Out:
# s3.Object(bucket_name='targetbucket-1234', key='xetra_daiy_report_2023-04-04_02-47-29.parquet')

# %% [markdown]
# ## checking

# %%
for obj in target_bucket.objects.all():
    print(obj.key)
# Out:
# xetra_daiy_report2023-04-04_02-07-12.parquet
# xetra_daiy_report_2023-04-04_02-13-42.parquet
# xetra_daiy_report_2023-04-04_02-47-29.parquet

# %%
prq_obj = target_bucket.Object(key='xetra_daiy_report_2023-04-04_02-47-29.parquet').get().get('Body').read()

# %%
data = BytesIO(prq_obj)
df_report = pd.read_parquet(data)

# %%
df_report
# Out:
#                ISIN        Date  opening_price_euro  closing_price_euro
# 0      AT000000STR1  2022-12-23               37.00               37.95  \
# 1      AT000000STR1  2022-12-24               36.05               36.10
# 2      AT000000STR1  2022-12-25               36.10               37.70
# 3      AT000000STR1  2022-12-26               36.10               37.70
# 4      AT000000STR1  2022-12-27               36.10               37.70
# ...             ...         ...                 ...                 ...
# 28846  XS2434891219  2022-12-27                3.44                3.50
# 28847  XS2434891219  2022-12-28                3.44                3.66
# 28848  XS2434891219  2022-12-29                3.44                3.66
# 28849  XS2434891219  2022-12-30                3.44                3.66
# 28850  XS2434891219  2022-12-31                3.44                3.66
#
#        minimun_price_euro  maximun_price_euro  daily_traded_volume
# 0                   37.00               37.95                  396  \
# 1                   35.65               37.05                 1838
# 2                   36.10               37.70                 2864
# 3                   36.10               37.70                 2864
# 4                   36.10               37.70                 2864
# ...                   ...                 ...                  ...
# 28846                3.44                3.50                    0
# 28847                3.42                3.66                    0
# 28848                3.42                3.66                    0
# 28849                3.42                3.66                    0
# 28850                3.42                3.66                    0
#
#        percentage_change_prev%
# 0                         2.99
# 1                        -4.87
# 2                         4.43
# 3                         0.00
# 4                         0.00
# ...                        ...
# 28846                     0.00
# 28847                     4.53
# 28848                     0.00
# 28849                     0.00
# 28850                     0.00
#
# [28851 rows x 8 columns]
